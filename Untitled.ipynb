# %%
Pkg.clone("https://github.com/ellenjunghyunkim/MyMatching.jl")
# Out:
# INFO: Cloning MyMatching from https://github.com/ellenjunghyunkim/MyMatching.jl
# INFO: Computing changes...
# INFO: Upgrading Blosc: v0.2.0 => v0.2.1
# INFO: Upgrading DataArrays: v0.3.12 => v0.4.1
# INFO: Upgrading Distributions: v0.12.5 => v0.13.0
# INFO: Upgrading Homebrew: v0.5.6 => v0.5.7
# INFO: Upgrading LegacyStrings: v0.2.1 => v0.2.2
# INFO: Upgrading LightGraphs: v0.7.5 => v0.7.7
# INFO: Upgrading StatsBase: v0.14.1 => v0.15.0
# INFO: Upgrading WebSockets: v0.2.2 => v0.2.3
# INFO: Upgrading ZMQ: v0.4.2 => v0.4.3
# WARNING: The following packages have been updated but were already imported:
# - ZMQ
# Restart Julia to use the updated versions.
# INFO: Building Blosc
# INFO: Building Rmath
# INFO: Building Homebrew
# Updated 2 taps (homebrew/core, homebrew/science).
# ==> New Formulae
# angular-cli
# asdf
# bartycrouch
# cython
# dcm2niix
# druid
# fsql
# get_iplayer
# grakn
# homebrew/science/alien-hunter
# homebrew/science/platypusvar
# homebrew/science/yices
# jhipster
# libmypaint
# mariadb@10.1
# rustup-init
# vips
# zeromq@4.1
# ==> Updated Formulae
# abcl
# advancemame
# afl-fuzz
# algernon
# allure
# ammonite-repl
# ansible
# apache-flink
# arangodb
# archi-steam-farm
# armor
# artifactory
# aubio
# awf
# aws-sdk-cpp
# awscli
# babl
# bandcamp-dl
# basex
# bastet
# bazel
# bear
# bee
# binaryen
# blackbox
# bmon
# calc
# cargo-completion
# certbot
# chakra
# checkstyle
# chromedriver
# chronograf
# cimg
# citus
# ckan
# closure-compiler
# cmake
# cmark-gfm
# cockroach
# collectd
# colordiff
# conan
# confuse
# consul
# consul-backinator
# consul-template
# convox
# cromwell
# crowdin
# dbhash
# dbt
# debianutils
# deis
# dfmt
# di
# diff-pdf
# diff-so-fancy
# django-completion
# dmd
# dmenu
# dnscrypt-wrapper
# dnsmasq
# docker-cloud
# docker-credential-helper
# docker-machine
# docker-machine-completion
# doctl
# dosbox
# dosbox-x
# dpkg
# duck
# easyrpg-player
# elasticsearch
# elixirscript
# elvish
# enigma
# etcd
# exiv2
# fabio
# fetch-crl
# ffmpeg
# fibjs
# file-formula
# filebeat
# firebase-cli
# fish
# flow
# fluent-bit
# folly
# fontconfig
# fonttools
# fop
# freeciv
# freeradius-server
# freetds
# fwup
# fzf
# gammaray
# gammu
# ganglia
# gdb
# gearman
# geckodriver
# geeqie
# geoipupdate
# getdns
# gexiv2
# git
# git-town
# gitbucket
# gitg
# gitlab-ci-multi-runner
# global
# gmic
# gnome-builder
# gnutls
# go
# go@1.7
# godep
# goenv
# goofys
# gphoto2
# grafana
# grails
# groonga
# heroku
# hg-fast-export
# highlight
# hive
# homebrew/science/anvio
# homebrew/science/armadillo
# homebrew/science/bpipe
# homebrew/science/cdo
# homebrew/science/diamond
# homebrew/science/dynare
# homebrew/science/getdp
# homebrew/science/htslib
# homebrew/science/igv
# homebrew/science/igvtools
# homebrew/science/insighttoolkit
# homebrew/science/iqtree
# homebrew/science/kaiju
# homebrew/science/libccd
# homebrew/science/libmatio
# homebrew/science/mummer
# homebrew/science/nanopolish
# homebrew/science/nco
# homebrew/science/nextflow
# homebrew/science/nixio
# homebrew/science/numdiff
# homebrew/science/opencollada
# homebrew/science/openmeeg
# homebrew/science/parallel-netcdf
# homebrew/science/rapsearch2
# homebrew/science/root6
# homebrew/science/snid
# homebrew/science/sumo
# homebrew/science/swetest
# homebrew/science/tamarin-prover
# homebrew/science/therion
# huexpress
# hugo
# hyper
# hyperscan
# i3status
# imagemagick
# imagemagick@6
# imageworsener
# imake
# influxdb@0.8
# instead
# ios-sim
# irssi
# jansson
# jboss-forge
# jenkins
# jenkins-lts
# jfrog-cli-go
# jmeter
# jruby
# jsonschema2pojo
# juju
# juju@1.25
# jvgrep
# kapacitor
# kerl
# kibana
# knot
# knot-resolver
# kobalt
# kompose
# kops
# lablgtk
# lastpass-cli
# latex2rtf
# latexila
# leaps
# lfe
# libass
# libdap
# libextractor
# libgcrypt
# libgit2-glib
# libgphoto2
# libgweather
# libhttpseverywhere
# libimobiledevice
# libmagic
# libmicrohttpd
# liboping
# libphonenumber
# libplist
# libsass
# libtasn1
# libtermkey
# libtiff
# libuv
# libvidstab
# libvirt
# libxml2
# libzzip
# lincity-ng
# llnode
# lmdb
# logstash
# logtalk
# lolcat
# lxc
# makepkg
# mame
# mariadb
# mariadb@10.0
# media-info
# mediaconch
# menhir
# mercurial
# metabase
# metricbeat
# micro
# micropython
# mikutter
# minetest
# mingw-w64
# miniupnpc
# mongo-c-driver
# mono
# mosquitto
# mpd
# mpg123
# msgpack
# mtr
# mutt
# mvtools
# ncmpc
# ncmpcpp
# ne
# neo4j
# netpbm
# nghttp2
# node
# node-build
# node@4
# node@6
# notmuch
# npth
# nspr
# ntopng
# numpy
# offlineimap
# ola
# oniguruma
# onscripter
# openal-soft
# opencoarrays
# openldap
# openssl
# openssl@1.1
# opus
# osc
# osh
# osquery
# p11-kit
# pachi
# packetbeat
# paket
# pandoc-citeproc
# pango
# pcap_dnsproxy
# pcsc-lite
# pdf2htmlex
# pdftoedn
# pgcli
# pgpdump
# pgplot
# phoronix-test-suite
# pilosa
# planck
# ponscripter-sekai
# poppler
# portmidi
# postgrest
# ppsspp
# pre-commit
# prometheus
# purescript
# pyexiv2
# pyinvoke
# pypy
# pypy3
# qbs
# qcachegrind
# qt
# radare2
# rancher-cli
# rbenv-ctags
# re2
# rebar@3
# riemann-client
# rmlint
# rocksdb
# rom-tools
# roswell
# rpm
# rswift
# rtags
# rtv
# ruby-build
# rust
# s6
# sane-backends
# sassc
# saxon
# sbcl
# sdl2_mixer
# sdl_mixer
# sdl_sound
# servus
# sfcgal
# shc
# shellshare
# shfmt
# sjk
# smali
# smlnj
# sourcekitten
# sourcery
# sphinx-doc
# sqldiff
# sqlite
# sqlite-analyzer
# sqlmap
# squid
# sslyze
# stern
# storm
# strongswan
# supertux
# supervisor
# svgcleaner
# swiftformat
# swiftlint
# syncthing
# tbb
# telegraf
# termius
# terraform
# terragrunt
# tesseract
# the_silver_searcher
# tippecanoe
# tmux
# tnef
# todolist
# tor
# translate-shell
# treefrog
# twine-pypi
# typescript
# ufoai
# unrar
# urh
# vapoursynth
# vault
# vim
# wartremover
# webpack
# wesnoth
# wget
# wine
# wireshark
# wpcli-completion
# xmount
# xonsh
# xsv
# yank
# yara
# yarn
# yasm
# yaz
# yle-dl
# youtube-dl
# yubico-piv-tool
# zanata-client
# ==> Renamed Formulae
# homebrew/science/samtools-0.1 -> homebrew/science/samtools@0.1
# ==> Deleted Formulae
# autotrace
# homebrew/science/vips
# libtess2
# snescom
# xplanetfx
# INFO: Building EzXML
# INFO: Building HDF5
# INFO: Building HttpParser
# WARNING: BinDeps.shlib_ext is deprecated.
#   likely near /Users/ellen/.julia/v0.5/HttpParser/deps/build.jl:38
# INFO: Building MbedTLS
# Using system libraries...
# INFO: Building ZMQ

# %%
using MyMatching

# %%
const _deferred_acceptance = my_deferred_acceptance
# Out:
# my_deferred_acceptance (generic function with 1 method)
