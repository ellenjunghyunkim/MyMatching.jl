# %% [markdown]
# 金正賢です。 MyMatchingのコードは以下より https://github.com/ellenjunghyunkim/MyMatching.jl/blob/master/src/MyMatching.jl my_deferred_acceptanceのデモです。

# %%
using MyMatching

# %%
Pkg.checkout("MyMatching")
# Out:
# INFO: Checking out MyMatching master...
# INFO: Pulling MyMatching latest master...
# INFO: Upgrading Blink: v0.5.2 => v0.5.3
# INFO: Upgrading FileIO: v0.3.1 => v0.4.1
# INFO: Upgrading Homebrew: v0.5.7 => v0.5.8
# INFO: Upgrading IJulia: v1.5.0 => v1.5.1
# INFO: Upgrading JLD: v0.6.10 => v0.6.11
# INFO: Upgrading PlotUtils: v0.4.1 => v0.4.2
# INFO: Upgrading Plots: v0.11.3 => v0.11.4
# INFO: Upgrading PyCall: v1.12.0 => v1.13.0
# INFO: Upgrading Rmath: v0.1.6 => v0.1.7
# WARNING: The following packages have been updated but were already imported:
# - IJulia
# Restart Julia to use the updated versions.
# INFO: Building HttpParser
# WARNING: BinDeps.shlib_ext is deprecated.
#   likely near /Users/ellen/.julia/v0.5/HttpParser/deps/build.jl:38
# INFO: Building Homebrew
# Updated 2 taps (homebrew/core, homebrew/science).
# ==> New Formulae
# apache-arrow
# bitcoin
# docker2aci
# dwarf
# erlang@19
# faas-cli
# fd
# freedink
# gradle-completion
# iamy
# insect
# ipython
# ipython@5
# jose
# kubectx
# libopusenc
# mruby-cli
# neovim
# openfortivpn
# overmind
# pycodestyle
# tokei
# ==> Updated Formulae
# afflib
# afl-fuzz
# allure
# amazon-ecs-cli
# ammonite-repl
# amqp-cpp
# angband
# angular-cli
# ansifilter
# ansiweather
# ant@1.9
# antigen
# apache-flink
# apache-zeppelin
# apktool
# app-engine-go-64
# app-engine-java
# appscale-tools
# apr
# apr-util
# arangodb
# archi-steam-farm
# armor
# artifactory
# aurora-cli
# automake
# aws-sdk-cpp
# awscli
# azure-cli
# baresip
# bash-completion@2
# bazel
# bear
# binaryen
# bind
# bitrise
# bluepill
# bro
# c-ares
# caddy
# cairo
# cake
# camlp4
# camlp5
# capnp
# chakra
# checkstyle
# chkrootkit
# chronograf
# cimg
# cjdns
# closure-compiler
# cmocka
# cockroach
# collector-sidecar
# compcert
# compose2kube
# conan
# consul
# consul-backinator
# consul-template
# convmv
# convox
# couchdb
# cromwell
# crowdin
# crystal-lang
# csmith
# ctop
# curl
# dar
# davmail
# dbus
# dcd
# dcm2niix
# dcos-cli
# dependency-check
# dhall-json
# dialog
# dieharder
# diffoscope
# direnv
# django-completion
# dnsmasq
# dnsviz
# docker-compose
# docker-compose-completion
# docker-credential-helper
# docker-machine
# docker-machine-completion
# docker-machine-driver-vultr
# docker-machine-driver-xhyve
# docutils
# dovecot
# druid
# ebook-tools
# ecl
# efl
# eigen
# elasticsearch
# elixir
# erlang
# etcd
# exercism
# exiftool
# expat
# fabric
# feedgnuplot
# feh
# fibjs
# ficy
# filebeat
# fio
# fits
# flatbuffers
# fleetctl
# flow
# flowgrind
# fluent-bit
# fmt
# fobis
# folly
# format-udf
# freetds
# frei0r
# fsql
# fuse-emulator
# fuse-zip
# fuseki
# fwup
# galen
# gammu
# gauge
# gegl
# getdns
# ghi
# ghostscript
# git
# git-annex
# git-ftp
# git-lfs
# gitbucket
# giter8
# gitlab-ci-multi-runner
# gjs
# gkrellm
# glib
# glibmm
# gmic
# gnome-recipes
# gnuradio
# gofabric8
# goofys
# gor
# gradle
# grails
# grep
# groonga
# groovy
# grpc
# gsl
# gsmartcontrol
# gst-editing-services
# gst-libav
# gst-plugins-bad
# gst-plugins-base
# gst-plugins-good
# gst-plugins-ugly
# gst-python
# gst-rtsp-server
# gst-validate
# gstreamer
# gtk+3
# gtkmm3
# gtksourceview3
# gucharmap
# haproxy
# harfbuzz
# heroku
# hg-fast-export
# highlight
# hledger
# homebrew/science/analysis
# homebrew/science/andi
# homebrew/science/anvio
# homebrew/science/apophenia
# homebrew/science/arpack
# homebrew/science/art
# homebrew/science/bamm
# homebrew/science/bayestraits
# homebrew/science/beast2
# homebrew/science/bowtie
# homebrew/science/cgns
# homebrew/science/clinfo
# homebrew/science/clonehd
# homebrew/science/cmdstan
# homebrew/science/cmor
# homebrew/science/coinmp
# homebrew/science/diamond
# homebrew/science/dwgsim
# homebrew/science/dynare
# homebrew/science/ea-utils
# homebrew/science/enblend-enfuse
# homebrew/science/express
# homebrew/science/fgsl
# homebrew/science/freec
# homebrew/science/getdp
# homebrew/science/glpk
# homebrew/science/gmsh
# homebrew/science/gmt
# homebrew/science/gmt4
# homebrew/science/gnuastro
# homebrew/science/gnudatalanguage
# homebrew/science/gromacs
# homebrew/science/hotspot
# homebrew/science/libbi
# homebrew/science/libsbol
# homebrew/science/libsequence
# homebrew/science/lmod
# homebrew/science/mad-x
# homebrew/science/mash
# homebrew/science/mathgl
# homebrew/science/meme
# homebrew/science/mummer
# homebrew/science/nextflow
# homebrew/science/opencollada
# homebrew/science/orthofinder
# homebrew/science/oswitch
# homebrew/science/packmol
# homebrew/science/pcb
# homebrew/science/pillow
# homebrew/science/rainbow
# homebrew/science/root
# homebrew/science/root6
# homebrew/science/samtools
# homebrew/science/seqdb
# homebrew/science/siril
# homebrew/science/slicot
# homebrew/science/vcfanno
# homebrew/science/vigra
# homebrew/science/visp
# homebrew/science/vtk
# homebrew/science/wiggletools
# homebrew/science/wxmaxima
# homebrew/science/xmi-msim
# httpflow
# huexpress
# hugo
# hyperscan
# i2p
# ibex
# ideviceinstaller
# imagemagick
# imagemagick@6
# influxdb
# influxdb@0.8
# ios-sim
# ipbt
# iperf3
# ipfs
# ipv6calc
# isync
# jboss-forge
# jemalloc
# jenkins
# jenkins-lts
# jetty
# jetty-runner
# jhipster
# jruby
# jsoncpp
# jsonnet
# jsonschema2pojo
# juju
# jython
# khal
# kibana
# kitchen-sync
# knot
# knot-resolver
# kops
# kotlin
# kubernetes-cli
# kubernetes-helm
# lablgtk
# languagetool
# lapack
# lastpass-cli
# latexila
# leaps
# leveldb
# libbluray
# libepoxy
# libgcrypt
# libgosu
# libhttpseverywhere
# liblcf
# libmikmod
# libnfs
# libphonenumber
# libqalculate
# libraw
# libre
# librem
# libspectrum
# libtensorflow
# libupnp
# libzip
# llnode
# llvm
# logrotate
# logstash
# logtalk
# lsdvd
# lumo
# luvit
# lxc
# lynis
# macvim
# magic-wormhole
# mame
# mapcrafter
# mapserver
# mcabber
# media-info
# memcached
# menhir
# meson
# metricbeat
# mftrace
# mgba
# mikmod
# miller
# minio
# minio-mc
# minisat
# mkvtoolnix
# mockserver
# moco
# moe
# monetdb
# mongodb
# monit
# mp3blaster
# mpg123
# msgpack
# n
# nano
# nats-streaming-server
# ndpi
# neofetch
# nghttp2
# nifi
# nmap
# nnn
# node
# node-build
# nodeenv
# nss
# ocaml
# ocamlbuild
# ocamlsdl
# oniguruma
# openh264
# openrct2
# openttd
# openvpn
# opus
# orientdb
# oscats
# osquery
# osrm-backend
# packer
# packetbeat
# paket
# parallel
# passenger
# pdf-redact-tools
# pdftoedn
# pdnsrec
# pegtl
# percona-server
# perl
# phoronix-test-suite
# pick
# pike
# planck
# plantuml
# platformio
# pmd
# pngquant
# poco
# poppler
# postgrest
# ppsspp
# pqiv
# pre-commit
# prest
# presto
# prometheus
# pwntools
# pyenv
# pyinvoke
# qt
# rabbitmq
# rancher-cli
# rbenv
# re2
# redis-leveldb
# rex
# riemann-client
# rkhunter
# rmlint
# rocksdb
# rom-tools
# roswell
# rustup-init
# s3cmd
# s6
# saldl
# sbcl
# sbtenv
# scalaenv
# scamper
# scipy
# screen
# securefs
# shadowsocks-libev
# snappy
# snappystream
# snzip
# solr
# source-to-image
# sourcery
# sparkey
# sphinx-doc
# sqlmap
# srtp
# st
# stlink
# streamlink
# subversion
# svgcleaner
# swiftformat
# swiftlint
# syncthing
# syncthing-inotify
# tee-clc
# telegraf
# teleport
# terraform
# terragrunt
# texinfo
# texmath
# tinyxml2
# tippecanoe
# tldr
# tomcat
# tor
# translate-toolkit
# treefrog
# ttyd
# twarc
# typescript
# udunits
# unbound
# unrar
# vagrant-completion
# vala
# valgrind
# vdirsyncer
# vert.x
# vifm
# vim
# vim@7.4
# vnu
# wartremover
# webpack
# weechat
# whois
# winetricks
# wiredtiger
# wireguard-tools
# wtf
# xctool
# yarn
# yaws
# ykneomgr
# yle-dl
# youtube-dl
# zsh
# zurl
# ==> Renamed Formulae
# osh -> etsh
# ==> Deleted Formulae
# homebrew/science/tensorflow
# kibana@4.1
# INFO: Building MbedTLS
# Using system libraries...
# INFO: Building Conda
# INFO: Building ZMQ
# INFO: Building IJulia
# INFO: Installing Jupyter via the Conda package.
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /Users/ellen/.julia/v0.5/Conda/deps/usr:
#
# The following packages will be UPDATED:
#
#     conda: 4.3.21-py27_0 --> 4.3.22-py27_0
#
# conda-4.3.22-p 100% |###############################| Time: 0:00:02 220.49 kB/s
# INFO: Found Jupyter version 4.3.0: /Users/ellen/.julia/v0.5/Conda/deps/usr/bin/jupyter
# Writing IJulia kernelspec to /Users/ellen/.julia/v0.5/IJulia/deps/julia-0.5/kernel.json ...
# Installing julia kernelspec julia-0.5
# [InstallKernelSpec] Removing existing kernelspec in /Users/ellen/Library/Jupyter/kernels/julia-0.5
# [InstallKernelSpec] Installed kernelspec julia-0.5 in /Users/ellen/Library/Jupyter/kernels/julia-0.5
# INFO: Building Blosc
# INFO: Building HDF5
# INFO: Building Plots
# INFO: Building PyCall
# Fetching package metadata ...........
# Solving package specifications: .
#
# Package plan for installation in environment /Users/ellen/.julia/v0.5/Conda/deps/usr:
#
# The following packages will be UPDATED:
#
#     matplotlib: 2.0.2-np112py27_0 --> 2.0.2-np113py27_0
#     numpy:      1.12.1-py27_0     --> 1.13.0-py27_0
#
# numpy-1.13.0-p 100% |###############################| Time: 0:00:19 190.81 kB/s
# matplotlib-2.0 100% |###############################| Time: 0:00:40 214.74 kB/s:00:06 321.66 kB/s       | Time: 0:00:20 266.06 kB/s
# INFO: PyCall is using /Users/ellen/.julia/v0.5/Conda/deps/usr/bin/python (Python 2.7.13) at /Users/ellen/.julia/v0.5/Conda/deps/usr/bin/python, libpython = /Users/ellen/.julia/v0.5/Conda/deps/usr/lib/libpython2.7
# INFO: /Users/ellen/.julia/v0.5/PyCall/deps/deps.jl has not changed
# INFO: /Users/ellen/.julia/v0.5/PyCall/deps/PYTHON has not changed
# INFO: Building Rmath

# %%
Pkg.test("MyMatching")
# Out:
# INFO: Testing MyMatching

# %%
m_prefs = [[3], [3, 2, 1], [1, 3, 2], [3, 1]];
f_prefs = [[2, 3], [2, 3, 4, 1], [4, 1, 2]];

# %%
my_deferred_acceptance(m_prefs, f_prefs)
# Out:
# ([0,2,1,3],[3,2,4])

# %%
prop_prefs = [[2], [2, 1], [2, 1], [1, 2, 3, 4], [2, 1, 4, 3], [2, 3, 1, 4], [2, 1, 4, 3], [4, 2, 1, 3]];

# %%
resp_prefs = [[3, 7], [7, 8, 5, 1, 2, 3, 4, 6], [2, 5, 8, 1, 3, 4, 7], [2, 5, 1, 3, 6, 4, 7]];

# %%
caps = [2, 2, 2, 2];

# %%
my_deferred_acceptance(prop_prefs::Vector{Vector{Int}},
                                resp_prefs::Vector{Vector{Int}},
                                caps::Vector{Int})
# Out:
# MethodError: no method matching my_deferred_acceptance(::Array{Array{Int64,1},1}, ::Array{Array{Int64,1},1}, ::Array{Int64,1})
# Closest candidates are:
#   my_deferred_acceptance(::Any, ::Any) at /Users/ellen/.julia/v0.5/MyMatching/src/MyMatching.jl:5
